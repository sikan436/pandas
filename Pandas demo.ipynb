# %%
import pandas as pd

# %%
df=pd.read_csv(r'survey_results_public.csv',index_col="Respondent")

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88883 entries, 1 to 88863
# Data columns (total 84 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MainBranch              88331 non-null  object
#  1   Hobbyist                88883 non-null  object
#  2   OpenSourcer             88883 non-null  object
#  3   OpenSource              86842 non-null  object
#  4   Employment              87181 non-null  object
#  5   Country                 88751 non-null  object
#  6   Student                 87014 non-null  object
#  7   EdLevel                 86390 non-null  object
#  8   UndergradMajor          75614 non-null  object
#  9   EduOther                84260 non-null  object
#  10  OrgSize                 71791 non-null  object
#  11  DevType                 81335 non-null  object
#  12  YearsCode               87938 non-null  object
#  13  Age1stCode              87634 non-null  object
# ...

# %%
schema_df=pd.read_csv(r'survey_results_schema.csv',index_col="Column")

# %%
schema_df.head()
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
df.Hobbyist
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource', 'Employment',
#        'Country', 'Student', 'EdLevel', 'UndergradMajor', 'EduOther',
#        'OrgSize', 'DevType', 'YearsCode', 'Age1stCode', 'YearsCodePro',
#        'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney', 'MgrWant', 'JobSeek',
#        'LastHireDate', 'LastInt', 'FizzBuzz', 'JobFactors', 'ResumeUpdate',
#        'CurrencySymbol', 'CurrencyDesc', 'CompTotal', 'CompFreq',
#        'ConvertedComp', 'WorkWeekHrs', 'WorkPlan', 'WorkChallenge',
#        'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev', 'CodeRevHrs', 'UnitTests',
#        'PurchaseHow', 'PurchaseWhat', 'LanguageWorkedWith',
#        'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df.Hobbyist
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df.loc[0:2,'Hobbyist':"Employment"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.loc[0:2,'Hobbyist':"Employment"]
#
# ...

# %%
countries=["United States","India","United Kingdom","Germany","Canada"]

# %%
filt=df["Country"].isin(countries)

# %%
df.loc[filt,"Country"]

# %%
lang=df["LanguageWorkedWith"].str.contains("Python",na=False)

# %%
df.loc[lang,"LanguageWorkedWith"]

# %%
df.loc[lang]

# %%
df.rename(columns={"ConvertedComp":"SalaryUSD"},inplace="True")

# %%
df.columns

# %%
df["Hobbyist"]

# %%
def Yes_No(name):
    if name=="Yes":
        return "True"
    else:
        return "False"

# %%
df["Hobbyist"].apply(Yes_No)

# %%
df

# %%
df.sort_values(by="Country",inplace=True)

# %%
df

# %%
df.columns

# %%
df[["Country","ConvertedComp"]].head(10)

# %%
fin=df["Country"]=="Afghanistan"

# %%
df[fin]

# %%
df["ConvertedComp"].nlargest(10)

# %%
df.nlargest(10,"ConvertedComp")

# %%
df["ConvertedComp"]

# %%
df["ConvertedComp"].head(10)

# %%
df["ConvertedComp"].median()

# %%
df.median()

# %%
df.describe()

# %%
df["Hobbyist"].count()

# %%
df["Hobbyist"].values_count()

# %%
df["Hobbyist"].value_counts()

# %% [raw]
# df["SocialMedia"].value_counts()

# %%
df["SocialMedia"].value_counts().sort_values()

# %%
df["SocialMedia"].value_counts().sort_values(ascending=False)

# %%
df["Country"].value_counts()

# %%
df.groupby["Country"]

# %%
df.groupby(["Country"])

# %%
country_grp=df.groupby(["Country"])

# %%
country_grp.get_group("India")

# %%
country_grp.get_group()

# %%
df["Country"]=="India"

# %%
fin=df["Country"]=="India"

# %%
df.loc[fin]["SocialMedia"].value_counts()

# %%
country_grp["SocialMedia"].value_counts().head(30)

# %%
country_grp["ConvertedComp"].value_counts()

# %%
country_grp["ConvertedComp"].median()

# %%
country_grp["ConvertedComp"].agg(["median","mean"])

# %%
filt=df["Country"]=="India"

# %%
df.loc[filt].str.contains("Python")

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python")

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").sum()

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").value_counts()

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").value_counts().loc[True]

# %%
df.loc[filt]["LanguageWorkedWith"].str.contains("Python").sum()

# %%
country_grp["LanguageWorkedWith"].str.contains("Python").sum()

# %%
country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum() )

# %%
df.columns

# %%
df["Country"]

# %%
df["Country"].values_count()

# %%
type(df["Country"].value_counts())

# %%
num_ppl=df["Country"].value_counts()

# %%
num_ppl

# %%
knows_python=country_grp["LanguageWorkedWith"].apply(lambda x: x.str.contains("Python").sum() )

# %%
knows_python

# %%
df_per_ppl_python=pd.concat([knows_python,num_ppl],axis="columns")

# %%
df_per_ppl_python

# %%
df_per_ppl_python.rename(columns={"LanguageWorkedWith":"ppl_knows_python","count":"total_ppl"},inplace=True)

# %%
df_per_ppl_python["per_ppl"]=df_per_ppl_python["ppl_knows_python"]/df_per_ppl_python["total_ppl"]*100

# %%
df_per_ppl_python

# %%
df_per_ppl_python
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_per_ppl_python
#
# NameError: name 'df_per_ppl_python' is not defined

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...
